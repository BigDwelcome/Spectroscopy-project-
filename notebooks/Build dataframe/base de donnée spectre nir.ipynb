# %% [markdown]
# # Objectif
#
# - Lecture de fichier format .mat en python
# - Création d'un fichier format python pour la suite.

# %%
import this
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!

# %%
import pandas as pd 
import pickle
from scipy.io import loadmat

# %%
data_mat = loadmat("../../data/raw/mmc3.mat")

# %%
data_mat.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'Xcal', 'Xtest', 'ycal', 'ytest', 'xaxis', 'SpectraTotal'])

# %%
data_mat
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: PCWIN64, Created on: Wed Jul 12 14:26:57 2017',
#  '__version__': '1.0',
#  '__globals__': [],
#  'Xcal': array([[0.09726673, 0.09665692, 0.09647957, ..., 1.7749269 , 1.80301487,
#          1.82188439],
#         [0.09753246, 0.09808734, 0.09856604, ..., 1.77051747, 1.77905619,
#          1.79310989],
#         [0.09983794, 0.09924221, 0.09834059, ..., 1.72213149, 1.73719978,
#          1.74640679],
#         ...,
#         [0.12481391, 0.1243458 , 0.1240458 , ..., 1.69346535, 1.70817029,
#          1.71857595],
#         [0.12182127, 0.12254774, 0.12319381, ..., 1.68769848, 1.70817184,
#          1.71731627],
#         [0.1192606 , 0.11923965, 0.11924606, ..., 1.67786789, 1.70649791,
#          1.71423686]]),
#  'Xtest': array([[0.09698751, 0.09664844, 0.09620344, ..., 1.72769797, 1.7392199 ,
#          1.73566878],
#         [0.09865905, 0.09874762, 0.09835422, ..., 1.73615968, 1.75319409,
#          1.75213194],
# ...

# %%
## sauvegarde des donnéees d'entrainements
Xtrain = data_mat["Xcal"]
ytrain = data_mat["ycal"] 

## sauvegarde des données de test
Xtest = data_mat["Xtest"]
ytest = data_mat["ytest"]

# sauvegarde de toutes les données spectrales
X = data_mat["SpectraTotal"]
wavelengths = data_mat["xaxis"].flatten()

## sauvegarde au format pickle
with open("../../data/processed/mmc3.pkl", "wb") as f:
    pickle.dump((s), f)
